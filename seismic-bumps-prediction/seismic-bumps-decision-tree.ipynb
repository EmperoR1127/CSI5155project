# %%
# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals

# Common imports
import numpy as np
import os
from scipy.io import arff
import pandas as pd

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Where to save the figures
PROJECT_ROOT_DIR = "/Users/EmperoR/ml/datasets/seismic-bumps/"

def save_fig(fig_id, tight_layout=True):
    path = os.path.join(PROJECT_ROOT_DIR, "images", fig_id + ".png")
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format='png', dpi=300)

data = arff.loadarff('/Users/EmperoR/ml/datasets/seismic-bumps/seismic-bumps.arff')
seismic_bumps_data = pd.DataFrame(data[0])
#pre-process the train_set
train_labels = seismic_bumps_data[["class"]].copy()
train_set = seismic_bumps_data.drop(["class"], axis=1)
train_labels["class"] = train_labels["class"].map(lambda x: str(x)[2])
train_set_num = seismic_bumps_data.drop(["seismic","seismoacoustic","shift", "ghazard", "class"], axis=1)
train_set_cat = seismic_bumps_data.drop(["genergy","gpuls","gdenergy", "gdpuls", "nbumps", "nbumps2", "nbumps3", "nbumps4", "nbumps5", "nbumps6", "nbumps7", "nbumps89", "energy", "maxenergy", "class"], axis=1)
#build the pipeline
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
num_pipeline = Pipeline([('imputer', SimpleImputer(strategy="median")),('std_scaler', StandardScaler()),])
full_pipeline = ColumnTransformer([("num", num_pipeline, list(train_set_num)),("cat", OneHotEncoder(), list(train_set_cat)),])
#prepare the data
train_set_prepared = full_pipeline.fit_transform(train_set)
#prepare the target
encoder = LabelEncoder()
train_labels_prepared = encoder.fit_transform(train_labels)
# Out:
# //anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
#train the model using 10-fold cross validation and get the confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
dt_clf = DecisionTreeClassifier()
train_prediction = cross_val_predict(dt_clf.fit(train_set_prepared, train_labels_prepared), train_set_prepared, train_labels_prepared, cv=10)
confusion_matrix(train_labels_prepared, train_prediction)
# Out:
# array([[2153,  261],
#        [ 148,   22]])

# %%
from sklearn.tree.export import export_text
dt_feature_names = ["seismic-1","seismic-2","seismoacoustic-1","seismoacoustic-2","seismoacoustic-3","shift-1","shift-2","genergy","gpuls","gdenergy","gdpuls","ghazard-1","ghazard-2","ghazard-3", "nbumps", "nbumps2", "nbumps3", "nbumps4", "nbumps5", "nbumps6", "nbumps7", "nbumps89", "energy", "maxenergy"]
r = export_text(dt_clf, feature_names=dt_feature_names)
print(r)
# Out:
# |--- seismoacoustic-3 <= 0.47
# |   |--- seismic-2 <= 1.43
# |   |   |--- seismic-1 <= -0.32
# |   |   |   |--- ghazard-3 <= -0.04
# |   |   |   |   |--- ghazard-3 <= -0.22
# |   |   |   |   |   |--- seismoacoustic-1 <= -1.21
# |   |   |   |   |   |   |--- seismoacoustic-2 <= -1.22
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- seismoacoustic-2 >  -1.22
# |   |   |   |   |   |   |   |--- seismic-1 <= -0.38
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- seismic-1 >  -0.38
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- seismoacoustic-1 >  -1.21
# |   |   |   |   |   |   |--- seismoacoustic-2 <= -0.08
# |   |   |   |   |   |   |   |--- seismic-1 <= -0.33
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- seismic-1 >  -0.33
# |   |   |   |   |   |   |   |   |--- seismic-1 <= -0.33
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- seismic-1 >  -0.33
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- seismoacoustic-2 >  -0.08
# |   |   |   |   |   |   |   |--- seismic-2 <= -0.60
# |   |   |   |   |   |   |   |   |--- seismic-2 <= -0.61
# |   |   |   |   |   |   |   |   |   |--- seismoacoustic-2 <= -0.05
# |   |   |   |   |   |   |   |   |   |   |--- seismoacoustic-1 <= -0.30
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- seismoacoustic-1 >  -0.30
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- seismoacoustic-2 >  -0.05
# |   |   |   |   |   |   |   |   |   |   |--- seismic-2 <= -0.85
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- seismic-2 >  -0.85
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- seismic-2 >  -0.61
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- seismic-2 >  -0.60
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- ghazard-3 >  -0.22
# |   |   |   |   |   |--- ghazard-3 <= -0.22
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- ghazard-3 >  -0.22
# |   |   |   |   |   |   |--- seismic-1 <= -0.35
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- seismic-1 >  -0.35
# |   |   |   |   |   |   |   |--- seismic-1 <= -0.35
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- seismic-1 >  -0.35
# |   |   |   |   |   |   |   |   |--- seismoacoustic-1 <= -0.88
# |   |   |   |   |   |   |   |   |   |--- seismoacoustic-2 <= -0.77
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- seismoacoustic-2 >  -0.77
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- seismoacoustic-1 >  -0.88
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- ghazard-3 >  -0.04
# |   |   |   |   |--- seismic-1 <= -0.38
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- seismic-1 >  -0.38
# |   |   |   |   |   |--- seismoacoustic-1 <= 0.56
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- seismoacoustic-1 >  0.56
# |   |   |   |   |   |   |--- ghazard-3 <= 0.01
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- ghazard-3 >  0.01
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |--- seismic-1 >  -0.32
# |   |   |   |--- seismic-1 <= -0.32
# |   |   |   |   |--- class: 1
# |   |   |   |--- seismic-1 >  -0.32
# |   |   |   |   |--- nbumps7 <= 0.50
# |   |   |   |   |   |--- seismoacoustic-2 <= -1.16
# |   |   |   |   |   |   |--- seismic-1 <= -0.02
# |   |   |   |   |   |   |   |--- seismic-2 <= -0.17
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- seismic-2 >  -0.17
# |   |   |   |   |   |   |   |   |--- nbumps2 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- nbumps2 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- seismic-1 >  -0.02
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- seismoacoustic-2 >  -1.16
# |   |   |   |   |   |   |--- seismoacoustic-2 <= 1.45
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- seismoacoustic-2 >  1.45
# |   |   |   |   |   |   |   |--- seismoacoustic-2 <= 1.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- seismoacoustic-2 >  1.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- nbumps7 >  0.50
# |   |   |   |   |   |--- seismoacoustic-2 <= 4.87
# |   |   |   |   |   |   |--- seismic-2 <= 0.49
# |   |   |   |   |   |   |   |--- seismic-2 <= 0.48
# |   |   |   |   |   |   |   |   |--- seismoacoustic-2 <= 1.58
# |   |   |   |   |   |   |   |   |   |--- seismic-1 <= -0.18
# |   |   |   |   |   |   |   |   |   |   |--- seismic-1 <= -0.18
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |   |--- seismic-1 >  -0.18
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- seismic-1 >  -0.18
# |   |   |   |   |   |   |   |   |   |   |--- seismoacoustic-2 <= -0.90
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- seismoacoustic-2 >  -0.90
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- seismoacoustic-2 >  1.58
# |   |   |   |   |   |   |   |   |   |--- seismoacoustic-2 <= 1.64
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- seismoacoustic-2 >  1.64
# |   |   |   |   |   |   |   |   |   |   |--- seismoacoustic-1 <= 2.13
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- seismoacoustic-1 >  2.13
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- seismic-2 >  0.48
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- seismic-2 >  0.49
# |   |   |   |   |   |   |   |--- seismic-2 <= 1.19
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- seismic-2 >  1.19
# |   |   |   |   |   |   |   |   |--- seismic-2 <= 1.20
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- seismic-2 >  1.20
# |   |   |   |   |   |   |   |   |   |--- ghazard-3 <= -0.07
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- ghazard-3 >  -0.07
# |   |   |   |   |   |   |   |   |   |   |--- seismic-1 <= -0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- seismic-1 >  -0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- seismoacoustic-2 >  4.87
# |   |   |   |   |   |   |--- seismic-2 <= 0.80
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- seismic-2 >  0.80
# |   |   |   |   |   |   |   |--- class: 0
# |   |--- seismic-2 >  1.43
# |   |   |--- shift-2 <= 0.14
# |   |   |   |--- seismic-2 <= 1.50
# |   |   |   |   |--- nbumps <= 0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- nbumps >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- seismic-2 >  1.50
# |   |   |   |   |--- seismic-2 <= 4.02
# |   |   |   |   |   |--- seismic-1 <= -0.19
# |   |   |   |   |   |   |--- seismoacoustic-1 <= 0.83
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- seismoacoustic-1 >  0.83
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- seismic-1 >  -0.19
# |   |   |   |   |   |   |--- seismoacoustic-1 <= -0.06
# |   |   |   |   |   |   |   |--- seismoacoustic-1 <= -0.08
# |   |   |   |   |   |   |   |   |--- nbumps4 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- nbumps4 >  0.50
# |   |   |   |   |   |   |   |   |   |--- seismic-1 <= 2.31
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- seismic-1 >  2.31
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- seismoacoustic-1 >  -0.08
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- seismoacoustic-1 >  -0.06
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- seismic-2 >  4.02
# |   |   |   |   |   |--- seismic-1 <= 3.44
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- seismic-1 >  3.44
# |   |   |   |   |   |   |--- seismic-2 <= 4.31
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- seismic-2 >  4.31
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- shift-2 >  0.14
# |   |   |   |--- seismic-1 <= 4.79
# |   |   |   |   |--- seismoacoustic-2 <= -0.53
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- seismoacoustic-2 >  -0.53
# |   |   |   |   |   |--- seismic-2 <= 2.48
# |   |   |   |   |   |   |--- seismic-1 <= 0.19
# |   |   |   |   |   |   |   |--- seismoacoustic-2 <= -0.21
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- seismoacoustic-2 >  -0.21
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- seismic-1 >  0.19
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- seismic-2 >  2.48
# |   |   |   |   |   |   |--- ghazard-2 <= -0.12
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- ghazard-2 >  -0.12
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- seismic-1 >  4.79
# |   |   |   |   |--- class: 0
# |--- seismoacoustic-3 >  0.47
# |   |--- seismic-2 <= 0.36
# |   |   |--- shift-2 <= 4.04
# |   |   |   |--- seismic-1 <= -0.30
# |   |   |   |   |--- seismic-1 <= -0.31
# |   |   |   |   |   |--- shift-2 <= 1.44
# |   |   |   |   |   |   |--- seismic-1 <= -0.33
# |   |   |   |   |   |   |   |--- seismic-1 <= -0.33
# |   |   |   |   |   |   |   |   |--- seismoacoustic-2 <= -0.47
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- seismoacoustic-2 >  -0.47
# |   |   |   |   |   |   |   |   |   |--- seismic-1 <= -0.37
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- seismic-1 >  -0.37
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- seismic-1 >  -0.33
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- seismic-1 >  -0.33
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- shift-2 >  1.44
# |   |   |   |   |   |   |--- ghazard-2 <= 0.19
# |   |   |   |   |   |   |   |--- seismic-1 <= -0.35
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- seismic-1 >  -0.35
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- ghazard-2 >  0.19
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- seismic-1 >  -0.31
# |   |   |   |   |   |--- ghazard-2 <= 0.10
# |   |   |   |   |   |   |--- seismoacoustic-2 <= -0.81
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- seismoacoustic-2 >  -0.81
# |   |   |   |   |   |   |   |--- seismoacoustic-2 <= -0.13
# |   |   |   |   |   |   |   |   |--- ghazard-2 <= -0.11
# |   |   |   |   |   |   |   |   |   |--- shift-2 <= 0.14
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- shift-2 >  0.14
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- ghazard-2 >  -0.11
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- seismoacoustic-2 >  -0.13
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- ghazard-2 >  0.10
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- seismic-1 >  -0.30
# |   |   |   |   |--- genergy <= 8.72
# |   |   |   |   |   |--- seismoacoustic-2 <= -1.43
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- seismoacoustic-2 >  -1.43
# |   |   |   |   |   |   |--- nbumps4 <= 0.50
# |   |   |   |   |   |   |   |--- ghazard-2 <= -0.20
# |   |   |   |   |   |   |   |   |--- seismoacoustic-1 <= -0.68
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- seismoacoustic-1 >  -0.68
# |   |   |   |   |   |   |   |   |   |--- ghazard-3 <= -0.20
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- ghazard-3 >  -0.20
# |   |   |   |   |   |   |   |   |   |   |--- seismoacoustic-1 <= -0.15
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- seismoacoustic-1 >  -0.15
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- ghazard-2 >  -0.20
# |   |   |   |   |   |   |   |   |--- seismic-2 <= 0.25
# |   |   |   |   |   |   |   |   |   |--- seismoacoustic-2 <= -0.08
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- seismoacoustic-2 >  -0.08
# |   |   |   |   |   |   |   |   |   |   |--- seismoacoustic-2 <= -0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- seismoacoustic-2 >  -0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- seismic-2 >  0.25
# |   |   |   |   |   |   |   |   |   |--- ghazard-3 <= -0.17
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- ghazard-3 >  -0.17
# |   |   |   |   |   |   |   |   |   |   |--- seismic-1 <= -0.16
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- seismic-1 >  -0.16
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- nbumps4 >  0.50
# |   |   |   |   |   |   |   |--- seismoacoustic-2 <= 0.23
# |   |   |   |   |   |   |   |   |--- shift-1 <= 3.96
# |   |   |   |   |   |   |   |   |   |--- ghazard-2 <= -0.21
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- ghazard-2 >  -0.21
# |   |   |   |   |   |   |   |   |   |   |--- seismoacoustic-2 <= 0.19
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- seismoacoustic-2 >  0.19
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- shift-1 >  3.96
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- seismoacoustic-2 >  0.23
# |   |   |   |   |   |   |   |   |--- seismoacoustic-2 <= 1.41
# |   |   |   |   |   |   |   |   |   |--- ghazard-2 <= -0.19
# |   |   |   |   |   |   |   |   |   |   |--- ghazard-3 <= -0.19
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- ghazard-3 >  -0.19
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- ghazard-2 >  -0.19
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- seismoacoustic-2 >  1.41
# |   |   |   |   |   |   |   |   |   |--- seismoacoustic-1 <= 0.71
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- seismoacoustic-1 >  0.71
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- genergy >  8.72
# |   |   |   |   |   |--- class: 1
# |   |   |--- shift-2 >  4.04
# |   |   |   |--- seismic-2 <= -0.31
# |   |   |   |   |--- class: 0
# |   |   |   |--- seismic-2 >  -0.31
# |   |   |   |   |--- ghazard-2 <= 0.43
# |   |   |   |   |   |--- seismoacoustic-1 <= 0.13
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- seismoacoustic-1 >  0.13
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- ghazard-2 >  0.43
# |   |   |   |   |   |--- seismic-2 <= 0.21
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- seismic-2 >  0.21
# |   |   |   |   |   |   |--- class: 0
# |   |--- seismic-2 >  0.36
# |   |   |--- seismoacoustic-1 <= -0.52
# |   |   |   |--- seismoacoustic-1 <= -0.56
# |   |   |   |   |--- shift-1 <= 0.14
# |   |   |   |   |   |--- seismoacoustic-2 <= -0.95
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- seismoacoustic-2 >  -0.95
# |   |   |   |   |   |   |--- ghazard-2 <= 3.08
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- ghazard-2 >  3.08
# |   |   |   |   |   |   |   |--- shift-2 <= 1.44
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- shift-2 >  1.44
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- shift-1 >  0.14
# |   |   |   |   |   |--- ghazard-3 <= -0.14
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- ghazard-3 >  -0.14
# |   |   |   |   |   |   |--- seismic-2 <= 1.20
# |   |   |   |   |   |   |   |--- seismic-1 <= 0.01
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- seismic-1 >  0.01
# |   |   |   |   |   |   |   |   |--- ghazard-2 <= 0.11
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- ghazard-2 >  0.11
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- seismic-2 >  1.20
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- seismoacoustic-1 >  -0.56
# |   |   |   |   |--- class: 1
# |   |   |--- seismoacoustic-1 >  -0.52
# |   |   |   |--- shift-1 <= 0.14
# |   |   |   |   |--- nbumps5 <= 0.50
# |   |   |   |   |   |--- seismic-1 <= -0.16
# |   |   |   |   |   |   |--- seismic-2 <= 0.58
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- seismic-2 >  0.58
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- seismic-1 >  -0.16
# |   |   |   |   |   |   |--- shift-2 <= 4.04
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- shift-2 >  4.04
# |   |   |   |   |   |   |   |--- seismic-1 <= 3.05
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- seismic-1 >  3.05
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- nbumps5 >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- shift-1 >  0.14
# |   |   |   |   |--- seismic-2 <= 0.39
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- seismic-2 >  0.39
# |   |   |   |   |   |--- seismic-1 <= 1.90
# |   |   |   |   |   |   |--- ghazard-3 <= -0.14
# |   |   |   |   |   |   |   |--- seismoacoustic-1 <= -0.43
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- seismoacoustic-1 >  -0.43
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- ghazard-3 >  -0.14
# |   |   |   |   |   |   |   |--- ghazard-2 <= -0.04
# |   |   |   |   |   |   |   |   |--- seismoacoustic-1 <= 1.04
# |   |   |   |   |   |   |   |   |   |--- seismic-1 <= -0.17
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- seismic-1 >  -0.17
# |   |   |   |   |   |   |   |   |   |   |--- seismic-2 <= 2.53
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- seismic-2 >  2.53
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- seismoacoustic-1 >  1.04
# |   |   |   |   |   |   |   |   |   |--- ghazard-2 <= -0.12
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- ghazard-2 >  -0.12
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- ghazard-2 >  -0.04
# |   |   |   |   |   |   |   |   |--- seismic-2 <= 0.41
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- seismic-2 >  0.41
# |   |   |   |   |   |   |   |   |   |--- seismic-2 <= 3.46
# |   |   |   |   |   |   |   |   |   |   |--- seismoacoustic-2 <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- seismoacoustic-2 >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- seismic-2 >  3.46
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- seismic-1 >  1.90
# |   |   |   |   |   |   |--- seismoacoustic-3 <= 2.67
# |   |   |   |   |   |   |   |--- seismic-1 <= 3.21
# |   |   |   |   |   |   |   |   |--- seismic-2 <= 2.72
# |   |   |   |   |   |   |   |   |   |--- shift-1 <= 1.41
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- shift-1 >  1.41
# |   |   |   |   |   |   |   |   |   |   |--- seismoacoustic-1 <= -0.17
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- seismoacoustic-1 >  -0.17
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- seismic-2 >  2.72
# |   |   |   |   |   |   |   |   |   |--- seismoacoustic-1 <= 0.25
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- seismoacoustic-1 >  0.25
# |   |   |   |   |   |   |   |   |   |   |--- seismoacoustic-1 <= 0.70
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- seismoacoustic-1 >  0.70
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- seismic-1 >  3.21
# |   |   |   |   |   |   |   |   |--- genergy <= 5.13
# |   |   |   |   |   |   |   |   |   |--- ghazard-3 <= -0.14
# |   |   |   |   |   |   |   |   |   |   |--- seismoacoustic-1 <= -0.12
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- seismoacoustic-1 >  -0.12
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- ghazard-3 >  -0.14
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- genergy >  5.13
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- seismoacoustic-3 >  2.67
# |   |   |   |   |   |   |   |--- class: 1

# %%
#plot the tree
from sklearn.tree import plot_tree
dt_feature_names = ["seismic-1","seismic-2","seismoacoustic-1","seismoacoustic-2","seismoacoustic-3","shift-1","shift-2","genergy","gpuls","gdenergy","gdpuls","ghazard-1","ghazard-2","ghazard-3", "nbumps", "nbumps2", "nbumps3", "nbumps4", "nbumps5", "nbumps6", "nbumps7", "nbumps89", "energy", "maxenergy"]
plt.figure(figsize=(8, 6))
plot_tree(dt_clf, feature_names=dt_feature_names)
save_fig("decision_tree")
# Out:
# Saving figure decision_tree

# %%
#compute the precision and recall
from sklearn.metrics import precision_score, recall_score
precision_score = precision_score(train_labels_prepared, train_prediction)
recall_score = recall_score(train_labels_prepared, train_prediction)
print("precision is + %f" % precision_score)
print("recall is + %f" % recall_score)
# Out:
# precision is + 0.077739
# recall is + 0.129412

# %%
#plot the ROC curve
from sklearn.metrics import roc_curve
train_scores = cross_val_predict(dt_clf, train_set_prepared, train_labels_prepared, cv=10, method="predict_proba")
fpr, tpr, thresholds = roc_curve(train_labels_prepared, train_scores[:,1])
def plot_roc_curve(fpr, tpr, label=None):
    plt.plot(fpr, tpr, linewidth=2, label=label)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.axis([0, 1, 0, 1])
    plt.xlabel('False Positive Rate', fontsize=16)
    plt.ylabel('True Positive Rate', fontsize=16)

plt.figure(figsize=(8, 6))
plot_roc_curve(fpr, tpr)
save_fig("decision_tree_roc_curve")
plt.show()
# Out:
# Saving figure decision_tree_roc_curve

# %%
#compute the auc score
from sklearn.metrics import roc_auc_score
auc_score = roc_auc_score(train_labels_prepared, train_scores[:,1])
print("Model of decision tree auc score is %f" % auc_score)
# Out:
# Model of decision tree auc score is 0.528915

# %%
#dump model in a gzip compressed file
import joblib
joblib.dump(dt_clf, PROJECT_ROOT_DIR + 'decision_tree_model' + '.gz', compress=('gzip', 3))
# Out:
# ['/Users/EmperoR/ml/datasets/seismic-bumps/decision_tree_model.gz']
